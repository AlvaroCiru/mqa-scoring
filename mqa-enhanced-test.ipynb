# %%
#Script para evaluar una carpeta de datasets -> Especificar tanto la ruta de la carpeta como la ruta absoluta desde el jupyter notebook

import mqa_mod
from pathlib import Path

carpeta = Path('./Datasets TFG/Portal Español/')

abs_path = './Datasets TFG/Portal Español/'

lista_weight = []
lista_weight_extra = []
lista_mqa_keyword = []
lista_mqa_theme = []
lista_mqa_spatial = []
lista_mqa_temporal = []
lista_mqa_access = []
lista_mqa_download = []
lista_mqa_download_access = []
lista_mqa_format = []
lista_mqa_media = []
lista_mqa_media_voc = []
lista_mqa_non_propietary = []
lista_mqa_machine_readable = []
lista_mqa_shacl = []
lista_mqa_license = []
lista_mqa_license_voc = []
lista_mqa_rights = []
lista_mqa_rights_voc = []
lista_mqa_contact = []
lista_mqa_publisher = []
lista_mqa_rights2 = []
lista_mqa_bytesize = []
lista_mqa_issued = []
lista_mqa_modified = []
lista_n_keywords = []
lista_valuable_keywords = []
lista_relation_keywords = []
lista_file_size = []
lista_standard_time = []
lista_recent_time = []
lista_standard_theme = []
lista_relation_theme = []
lista_temp_recent = []
lista_mqa_title = []

archivos = [f.name for f in carpeta.iterdir() if f.is_file()]

for archivo in archivos:
    ruta_completa = f"{abs_path}{archivo}"    
    weight, weight_extra, mqa_keyword, mqa_theme, mqa_spatial, mqa_temporal, mqa_access, mqa_download, mqa_download_access, mqa_format, mqa_media, mqa_media_voc, mqa_non_propietary, mqa_machine_readable, mqa_shacl, mqa_license, mqa_license_voc, mqa_rights, mqa_rights_voc, mqa_contact, mqa_publisher, mqa_rights2, mqa_bytesize, mqa_issued, mqa_modified, n_keywords, valuable_keywords, relation_keywords, file_size, standard_time, recent_time, standard_theme, relation_theme, temp_recent, mqa_title = mqa_mod.main(ruta_completa)
    lista_weight.append(weight)
    lista_weight_extra.append(weight_extra)
    lista_mqa_keyword.append(mqa_keyword)
    lista_mqa_theme.append(mqa_theme)
    lista_mqa_spatial.append(mqa_spatial)
    lista_mqa_temporal.append(mqa_temporal)
    lista_mqa_access.append(mqa_access)
    lista_mqa_download.append(mqa_download)
    lista_mqa_download_access.append(mqa_download_access)
    lista_mqa_format.append(mqa_format)
    lista_mqa_media.append(mqa_media)
    lista_mqa_media_voc.append(mqa_media_voc)
    lista_mqa_non_propietary.append(mqa_non_propietary)
    lista_mqa_machine_readable.append(mqa_machine_readable)
    lista_mqa_shacl.append(mqa_shacl)
    lista_mqa_license.append(mqa_license)
    lista_mqa_license_voc.append(mqa_license_voc)
    lista_mqa_rights.append(mqa_rights)
    lista_mqa_rights_voc.append(mqa_rights_voc)
    lista_mqa_contact.append(mqa_contact)
    lista_mqa_publisher.append(mqa_publisher)
    lista_mqa_rights2.append(mqa_rights2)
    lista_mqa_bytesize.append(mqa_bytesize)
    lista_mqa_issued.append(mqa_issued)
    lista_mqa_modified.append(mqa_modified)
    lista_n_keywords.append(n_keywords)
    lista_valuable_keywords.append(valuable_keywords)
    lista_relation_keywords.append(relation_keywords)
    lista_file_size.append(file_size)
    lista_standard_time.append(standard_time)
    lista_recent_time.append(recent_time)
    lista_standard_theme.append(standard_theme)
    lista_relation_theme.append(relation_theme)
    lista_temp_recent.append(temp_recent)
    lista_mqa_title.append(mqa_title)

# %%
#Script para evaluar un solo dataset (Especificar la ruta en la llamada a mqa_mod.main(RUTA_DEL_ARCHIVO)

import mqa_mod
from pathlib import Path


lista_weight = []
lista_weight_extra = []
lista_mqa_keyword = []
lista_mqa_theme = []
lista_mqa_spatial = []
lista_mqa_temporal = []
lista_mqa_access = []
lista_mqa_download = []
lista_mqa_download_access = []
lista_mqa_format = []
lista_mqa_media = []
lista_mqa_media_voc = []
lista_mqa_non_propietary = []
lista_mqa_machine_readable = []
lista_mqa_shacl = []
lista_mqa_license = []
lista_mqa_license_voc = []
lista_mqa_rights = []
lista_mqa_rights_voc = []
lista_mqa_contact = []
lista_mqa_publisher = []
lista_mqa_rights2 = []
lista_mqa_bytesize = []
lista_mqa_issued = []
lista_mqa_modified = []
lista_n_keywords = []
lista_valuable_keywords = []
lista_relation_keywords = []
lista_file_size = []
lista_standard_time = []
lista_recent_time = []
lista_standard_theme = []
lista_relation_theme = []
lista_temp_recent = []


weight, weight_extra, mqa_keyword, mqa_theme, mqa_spatial, mqa_temporal, mqa_access, mqa_download, mqa_download_access, mqa_format, mqa_media, mqa_media_voc, mqa_non_propietary, mqa_machine_readable, mqa_shacl, mqa_license, mqa_license_voc, mqa_rights, mqa_rights_voc, mqa_contact, mqa_publisher, mqa_rights2, mqa_bytesize, mqa_issued, mqa_modified, n_keywords, valuable_keywords, relation_keywords, file_size, standard_time, recent_time, standard_theme, relation_theme, temp_recent, mqa_title = mqa_mod.main('./SALTED_EUROPE/2b3d441b-255a-4e38-b1a9-86f984526f3a.rdf')
lista_weight.append(weight)
lista_weight_extra.append(weight_extra)
lista_mqa_keyword.append(mqa_keyword)
lista_mqa_theme.append(mqa_theme)
lista_mqa_spatial.append(mqa_spatial)
lista_mqa_temporal.append(mqa_temporal)
lista_mqa_access.append(mqa_access)
lista_mqa_download.append(mqa_download)
lista_mqa_download_access.append(mqa_download_access)
lista_mqa_format.append(mqa_format)
lista_mqa_media.append(mqa_media)
lista_mqa_media_voc.append(mqa_media_voc)
lista_mqa_non_propietary.append(mqa_non_propietary)
lista_mqa_machine_readable.append(mqa_machine_readable)
lista_mqa_shacl.append(mqa_shacl)
lista_mqa_license.append(mqa_license)
lista_mqa_license_voc.append(mqa_license_voc)
lista_mqa_rights.append(mqa_rights)
lista_mqa_rights_voc.append(mqa_rights_voc)
lista_mqa_contact.append(mqa_contact)
lista_mqa_publisher.append(mqa_publisher)
lista_mqa_rights2.append(mqa_rights2)
lista_mqa_bytesize.append(mqa_bytesize)
lista_mqa_issued.append(mqa_issued)
lista_mqa_modified.append(mqa_modified)
lista_n_keywords.append(n_keywords)
lista_valuable_keywords.append(valuable_keywords)
lista_relation_keywords.append(relation_keywords)
lista_file_size.append(file_size)
lista_standard_time.append(standard_time)
lista_recent_time.append(recent_time)
lista_standard_theme.append(standard_theme)
lista_relation_theme.append(relation_theme)
lista_temp_recent.append(temp_recent)

# %%
import pandas as pd

# Crear diccionario de DataFrames
d = {}

d['Evaluacion MQA'] = pd.DataFrame({
    'Nombre del dataset': archivos,
})

d['Facilidad de localización'] = pd.DataFrame({
    'Keyword': lista_mqa_keyword, 
    'Theme': lista_mqa_theme, 
    'Spatial': lista_mqa_spatial, 
    'Temporal': lista_mqa_temporal
})

d['Accesibilidad'] = pd.DataFrame({
    'AccessURL': lista_mqa_access, 
    'DownloadURL': lista_mqa_download, 
    'DownloadURL_access': lista_mqa_download_access
})

d['Interoperabilidad'] = pd.DataFrame({
    'Format': lista_mqa_format, 
    'MediaType': lista_mqa_media, 
    'Format+MediaType_voc': lista_mqa_media_voc, 
    'Non_propietary': lista_mqa_non_propietary, 
    'Machine_readable': lista_mqa_machine_readable, 
    'SHACL': lista_mqa_shacl
})

d['Reusabilidad'] = pd.DataFrame({
    'License': lista_mqa_license, 
    'License_voc': lista_mqa_license_voc, 
    'AccessRights': lista_mqa_rights, 
    'AccessRights_voc': lista_mqa_rights_voc, 
    'Contact': lista_mqa_contact, 
    'Publisher': lista_mqa_publisher
})

d['Contextualidad'] = pd.DataFrame({
    'Rights': lista_mqa_rights2, 
    'ByteSize': lista_mqa_bytesize, 
    'Issued': lista_mqa_issued, 
    'Modified': lista_mqa_modified
})

d['mqa-enhanced_Keywords'] = pd.DataFrame({
    'Nº Keywords': lista_n_keywords, 
    'Keywords_description': lista_relation_keywords
})

d['mqa-enhanced_Temporal'] = pd.DataFrame({
    'Archivo-activo': lista_temp_recent
})

d['mqa-enhanced_DownloadURL'] = pd.DataFrame({
    'FileSize adecuado': lista_file_size
})

d['mqa-enhanced_Publicación'] = pd.DataFrame({
    'Estándar XLSchema': lista_standard_time, 
    'Publicado_recientemente': lista_recent_time
})

d['mqa-enhanced_Tema'] = pd.DataFrame({
    'Theme_voc': lista_standard_theme, 
    'Theme_description': lista_relation_theme
})

# Concatenar todos los DataFrames en un único DataFrame
df_final = pd.concat(d, axis=1)

df_final
# Exportar el DataFrame final a un archivo Excel
#df_final.to_excel('YODA 2.xlsx', index=True)

# %%
def flatten_list(input_list):
    result = []
    for item in input_list:
        if isinstance(item, list):
            result.extend(flatten_list(item))  # Llamada recursiva si el item es una lista
        else:
            result.append(item)
    return result

# Ejemplo de uso
nested_list = ['a', ['b', 'c'], 'd', ['e', ['f', 'g']], 'h']
flattened_list = flatten_list(nested_list)
flattened_list
